# %%
# !nvidia-smi
# Out:
# Fri Jan  8 11:29:43 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.27.04    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   64C    P0    31W /  70W |    227MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# check if you run on GPU. Should print '/device:GPU:0'
# %tensorflow_version 2.x
import tensorflow as tf
device_name = tf.test.gpu_device_name()
if device_name != '/device:GPU:0':
  raise SystemError('GPU device not found')
print('Found GPU at: {}'.format(device_name))
# Out:
# Found GPU at: /device:GPU:0

# %%
# install pre requrment 
# !pip install SoundFile
# Out:
# Requirement already satisfied: SoundFile in /usr/local/lib/python3.6/dist-packages (0.10.3.post1)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.6/dist-packages (from SoundFile) (1.14.4)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.6/dist-packages (from cffi>=1.0->SoundFile) (2.20)

# %%
# clone our project
import os
# !pwd
! rm -r ex_5/
# !pwd
# !mkdir "ex_5"
# %cd 'ex_5'
# !ls
# !git clone https://github.com/gadididi/ex_5-machine-learning.git
# Out:
# /content
# /content
# /content/ex_5
# Cloning into 'ex_5-machine-learning'...
# remote: Enumerating objects: 7, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9112 (delta 2), reused 0 (delta 0), pack-reused 9105
# Receiving objects: 100% (9112/9112), 195.87 MiB | 33.81 MiB/s, done.
# Resolving deltas: 100% (25/25), done.
# Checking out files: 100% (9038/9038), done.

# %%
# %cd ex_5-machine-learning/
# !ls
# Out:
# /content/ex_5/ex_5-machine-learning
# cnn.py	     ex_5_ml.ipynb  gcommand_dataset.py  short_valid
# details.txt  ex_5.py	    short_train		 tmp_group_creator.py

# %%
# !python ex_5.py
# Out:
# epoch number:  1
#
# Tests set: Average loss: 0.0375, Accuracy: 436/1530 (28%)
#
# epoch number:  2
#
# Tests set: Average loss: 0.0307, Accuracy: 620/1530 (41%)
#
# epoch number:  3
#
# Tests set: Average loss: 0.0243, Accuracy: 789/1530 (52%)
#
# epoch number:  4
#
# Tests set: Average loss: 0.0206, Accuracy: 929/1530 (61%)
#
# epoch number:  5
#
# Tests set: Average loss: 0.1398, Accuracy: 960/1530 (63%)
#
# epoch number:  6
#
# Tests set: Average loss: 0.0162, Accuracy: 1067/1530 (70%)
#
# epoch number:  7
#
# Tests set: Average loss: 0.0262, Accuracy: 1142/1530 (75%)
#
# epoch number:  8
#
# Tests set: Average loss: 0.1441, Accuracy: 1142/1530 (75%)
#
# epoch number:  9
#
# Tests set: Average loss: 0.0143, Accuracy: 1168/1530 (76%)
#
# epoch number:  10
#
# Tests set: Average loss: 0.0524, Accuracy: 1096/1530 (72%)
#
# epoch number:  11
#
# Tests set: Average loss: 0.0319, Accuracy: 1177/1530 (77%)
#
# epoch number:  12
#
# Tests set: Average loss: 0.0135, Accuracy: 1195/1530 (78%)
#
# epoch number:  13
#
# Tests set: Average loss: 0.0755, Accuracy: 715/1530 (47%)
#
# epoch number:  14
#
# Tests set: Average loss: 0.0142, Accuracy: 1183/1530 (77%)
#
# epoch number:  15
#
# Tests set: Average loss: 0.0632, Accuracy: 1234/1530 (81%)
#
# epoch number:  16
#
# Tests set: Average loss: 0.0210, Accuracy: 1244/1530 (81%)
#
# epoch number:  17
#
# Tests set: Average loss: 0.0246, Accuracy: 1228/1530 (80%)
#
# epoch number:  18
#
# Tests set: Average loss: 0.0301, Accuracy: 1226/1530 (80%)
#
# epoch number:  19
#
# Tests set: Average loss: 0.1596, Accuracy: 786/1530 (51%)
#
# epoch number:  20
#
# Tests set: Average loss: 2.0838, Accuracy: 1006/1530 (66%)
